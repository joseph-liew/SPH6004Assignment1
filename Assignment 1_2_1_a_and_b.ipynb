# %% [markdown]
# **SVM non-continuous var**

# %% [markdown]
# SVM on all noncontin features (SMOTE)

# %%
see 1_2_1a

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier, SGDRegressor, RidgeCV, LassoCV
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split, KFold
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from collections import Counter
from imblearn.over_sampling import SMOTE, SMOTEN

#'''
pd.set_option("display.max_columns", None)
#X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state = 0) #train split

k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=None)

smoten_noncontin = pd.read_csv('smoten_noncontin.csv', index_col=False)

X = smoten_noncontin.drop('outcome',axis= 1)
y = smoten_noncontin['outcome']

print('SMOTEN non-contin')
print()

print('linear SGDClassifier SVM StandardScaler')
sgdClass = SGDClassifier(loss='hinge', penalty='l2', alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=1000, tol=0.001, shuffle=True, verbose=0, epsilon=0.1, n_jobs=None, random_state=None, learning_rate='optimal', eta0=0.0, power_t=0.5, early_stopping=False, validation_fraction=0.1, n_iter_no_change=5, class_weight=None, warm_start=False, average=False)
clf = make_pipeline(StandardScaler(), sgdClass)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']

print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('coef_')
print(clf[1].coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf[1].decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('linear SGDClassifier SVM RobustScaler')
clf = make_pipeline(RobustScaler(), sgdClass)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']

print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('coef_')
print(clf[1].coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf[1].decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')


print('Encoded non-contin')
print()

knn_imputed_noncontin = pd.read_csv('knn_imputed_noncontin.csv', index_col=False)

X = knn_imputed_noncontin.drop('outcome',axis= 1)
y = knn_imputed_noncontin['outcome']

print('linear SGDClassifier SVM StandardScaler')
sgdClass = SGDClassifier(loss='hinge', penalty='l2', alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=1000, tol=0.001, shuffle=True, verbose=0, epsilon=0.1, n_jobs=None, random_state=None, learning_rate='optimal', eta0=0.0, power_t=0.5, early_stopping=False, validation_fraction=0.1, n_iter_no_change=5, class_weight=None, warm_start=False, average=False)
clf = make_pipeline(StandardScaler(), sgdClass)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']

print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('coef_')
print(clf[1].coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf[1].decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('linear SGDClassifier SVM RobustScaler')
clf = make_pipeline(RobustScaler(), sgdClass)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']

print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('coef_')
print(clf[1].coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf[1].decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

'''
print('linear SGDRegressor loss equivalent to SVR, loss = epsilon_insensitive, StandardScaler')
sgdSVRLinear = SGDRegressor(loss='epsilon_insensitive', penalty='l2', alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=1000, tol=0.001, shuffle=True, verbose=0, epsilon=0.1, random_state=None, learning_rate='invscaling', eta0=0.01, power_t=0.25, early_stopping=False, validation_fraction=0.1, n_iter_no_change=5, warm_start=False, average=False)
clf = make_pipeline(StandardScaler(), sgdSVRLinear)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']

print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print(clf[1].coef_)
print(clf[1].intercept_)
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)

print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('linear SGDRegressor loss equivalent to SVR, loss = epsilon_insensitive, RobustScaler')
sgdSVRLinear = SGDRegressor(loss='epsilon_insensitive', penalty='l2', alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=1000, tol=0.001, shuffle=True, verbose=0, epsilon=0.1, random_state=None, learning_rate='invscaling', eta0=0.01, power_t=0.25, early_stopping=False, validation_fraction=0.1, n_iter_no_change=5, warm_start=False, average=False)
clf = make_pipeline(StandardScaler(), sgdSVRLinear)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']

print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print(clf[1].coef_)
print(clf[1].intercept_)
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)

print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')
'''
# Out:
# SMOTEN non-contin
#
# linear SGDClassifier SVM StandardScaler
# accuracy of each fold - [0.7031427758816837, 0.700938566552901, 0.685651308304892, 0.6916240045506257, 0.6963168373151308]
# Avg accuracy : 0.6955346985210467
# parameters
#  {'memory': None, 'steps': [('standardscaler', StandardScaler()), ('sgdclassifier', SGDClassifier())], 'verbose': False, 'standardscaler': StandardScaler(), 'sgdclassifier': SGDClassifier(), 'standardscaler__copy': True, 'standardscaler__with_mean': True, 'standardscaler__with_std': True, 'sgdclassifier__alpha': 0.0001, 'sgdclassifier__average': False, 'sgdclassifier__class_weight': None, 'sgdclassifier__early_stopping': False, 'sgdclassifier__epsilon': 0.1, 'sgdclassifier__eta0': 0.0, 'sgdclassifier__fit_intercept': True, 'sgdclassifier__l1_ratio': 0.15, 'sgdclassifier__learning_rate': 'optimal', 'sgdclassifier__loss': 'hinge', 'sgdclassifier__max_iter': 1000, 'sgdclassifier__n_iter_no_change': 5, 'sgdclassifier__n_jobs': None, 'sgdclassifier__penalty': 'l2', 'sgdclassifier__power_t': 0.5, 'sgdclassifier__random_state': None, 'sgdclassifier__shuffle': True, 'sgdclassifier__tol': 0.001, 'sgdclassifier__validation_fraction': 0.1, 'sgdclassifier__verbose': 0, 'sgdclassifier__warm_start': False}
# score
#  0.6994809442548351
# coef_
# [[ 5.62300003e-04  6.75471794e-02  9.63741204e-01  1.58855855e-03
#    6.70442683e-02 -2.15643041e-02]]
# intercept_
# [-0.03727723]
# fit
# 6 ['sofa_coagulation' 'sofa_cardiovascular' 'sofa_cns' 'sofa_renal' 'gender'
#  'charlson_comorbidity_index']
# decision function
#  [-0.95022728 -0.86582065  2.09456503 ...  2.20364291  0.27028311
#  -0.51581538]
# classification report
#                    precision    recall  f1-score   support
#
# Intubation False       0.66      0.82      0.73      7028
#  Intubation True       0.76      0.57      0.65      7036
#
#         accuracy                           0.70     14064
#        macro avg       0.71      0.70      0.69     14064
#     weighted avg       0.71      0.70      0.69     14064
#
# Micro-averaged One-vs-Rest ROC AUC score:
# 0.70
#
#
# linear SGDClassifier SVM RobustScaler
# F:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but SGDClassifier was fitted without feature names
#   warnings.warn(
# accuracy of each fold - [0.7052047781569966, 0.6862912400455062, 0.6944681456200228, 0.6978811149032992, 0.6978100113765643]
# Avg accuracy : 0.6963310580204778
# parameters
#  {'memory': None, 'steps': [('robustscaler', RobustScaler()), ('sgdclassifier', SGDClassifier())], 'verbose': False, 'robustscaler': RobustScaler(), 'sgdclassifier': SGDClassifier(), 'robustscaler__copy': True, 'robustscaler__quantile_range': (25.0, 75.0), 'robustscaler__unit_variance': False, 'robustscaler__with_centering': True, 'robustscaler__with_scaling': True, 'sgdclassifier__alpha': 0.0001, 'sgdclassifier__average': False, 'sgdclassifier__class_weight': None, 'sgdclassifier__early_stopping': False, 'sgdclassifier__epsilon': 0.1, 'sgdclassifier__eta0': 0.0, 'sgdclassifier__fit_intercept': True, 'sgdclassifier__l1_ratio': 0.15, 'sgdclassifier__learning_rate': 'optimal', 'sgdclassifier__loss': 'hinge', 'sgdclassifier__max_iter': 1000, 'sgdclassifier__n_iter_no_change': 5, 'sgdclassifier__n_jobs': None, 'sgdclassifier__penalty': 'l2', 'sgdclassifier__power_t': 0.5, 'sgdclassifier__random_state': None, 'sgdclassifier__shuffle': True, 'sgdclassifier__tol': 0.001, 'sgdclassifier__validation_fraction': 0.1, 'sgdclassifier__verbose': 0, 'sgdclassifier__warm_start': False}
# score
#  0.6987699089874858
# coef_
# [[-0.00807343 -0.04036715  1.50973131  0.05651401  0.1372483  -0.02152915]]
# intercept_
# [-0.27580789]
# fit
# 6 ['sofa_coagulation' 'sofa_cardiovascular' 'sofa_cns' 'sofa_renal' 'gender'
#  'charlson_comorbidity_index']
# decision function
#  [-0.61592534  0.88169583 -0.39794274 ...  0.84940211  4.49051879
#   2.79913532]
# classification report
#                    precision    recall  f1-score   support
#
# Intubation False       0.66      0.83      0.73      6996
#  Intubation True       0.77      0.57      0.66      7068
#
#         accuracy                           0.70     14064
#        macro avg       0.71      0.70      0.69     14064
#     weighted avg       0.71      0.70      0.69     14064
#
# Micro-averaged One-vs-Rest ROC AUC score:
# 0.70
#
#
# Encoded non-contin
#
# linear SGDClassifier SVM StandardScaler
# F:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but SGDClassifier was fitted without feature names
#   warnings.warn(
# F:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but SGDClassifier was fitted without feature names
#   warnings.warn(
# F:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# F:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# F:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy of each fold - [0.9627295149355988, 0.9654699917785695, 0.9682104686215401, 0.9628665387777473, 0.9586131286830204]
# Avg accuracy : 0.9635779285592954
# parameters
#  {'memory': None, 'steps': [('standardscaler', StandardScaler()), ('sgdclassifier', SGDClassifier())], 'verbose': False, 'standardscaler': StandardScaler(), 'sgdclassifier': SGDClassifier(), 'standardscaler__copy': True, 'standardscaler__with_mean': True, 'standardscaler__with_std': True, 'sgdclassifier__alpha': 0.0001, 'sgdclassifier__average': False, 'sgdclassifier__class_weight': None, 'sgdclassifier__early_stopping': False, 'sgdclassifier__epsilon': 0.1, 'sgdclassifier__eta0': 0.0, 'sgdclassifier__fit_intercept': True, 'sgdclassifier__l1_ratio': 0.15, 'sgdclassifier__learning_rate': 'optimal', 'sgdclassifier__loss': 'hinge', 'sgdclassifier__max_iter': 1000, 'sgdclassifier__n_iter_no_change': 5, 'sgdclassifier__n_jobs': None, 'sgdclassifier__penalty': 'l2', 'sgdclassifier__power_t': 0.5, 'sgdclassifier__random_state': None, 'sgdclassifier__shuffle': True, 'sgdclassifier__tol': 0.001, 'sgdclassifier__validation_fraction': 0.1, 'sgdclassifier__verbose': 0, 'sgdclassifier__warm_start': False}
# score
#  0.9648191285283639
# coef_
# [[-0.05577318 -0.03120523  0.03661373  0.07602567 -0.01038702 -0.0205618 ]]
# intercept_
# [-1.14900785]
# fit
# 6 ['sofa_coagulation' 'sofa_cardiovascular' 'sofa_cns' 'sofa_renal' 'gender'
#  'charlson_comorbidity_index']
# decision function
#  [-1.05370012 -0.97482651 -0.97683019 ... -1.10235451 -1.04828413
#  -1.10843237]
# classification report
#                    precision    recall  f1-score   support
#
# Intubation False       0.96      1.00      0.98      6995
#  Intubation True       0.00      0.00      0.00       302
#
#         accuracy                           0.96      7297
#        macro avg       0.48      0.50      0.49      7297
#     weighted avg       0.92      0.96      0.94      7297
#
# Micro-averaged One-vs-Rest ROC AUC score:
# 0.50
#
#
# linear SGDClassifier SVM RobustScaler
# accuracy of each fold - [0.9662921348314607, 0.9632776103041929, 0.963825705672787, 0.9632776103041929, 0.9612169384678635]
# Avg accuracy : 0.9635779999160994
# parameters
#  {'memory': None, 'steps': [('robustscaler', RobustScaler()), ('sgdclassifier', SGDClassifier())], 'verbose': False, 'robustscaler': RobustScaler(), 'sgdclassifier': SGDClassifier(), 'robustscaler__copy': True, 'robustscaler__quantile_range': (25.0, 75.0), 'robustscaler__unit_variance': False, 'robustscaler__with_centering': True, 'robustscaler__with_scaling': True, 'sgdclassifier__alpha': 0.0001, 'sgdclassifier__average': False, 'sgdclassifier__class_weight': None, 'sgdclassifier__early_stopping': False, 'sgdclassifier__epsilon': 0.1, 'sgdclassifier__eta0': 0.0, 'sgdclassifier__fit_intercept': True, 'sgdclassifier__l1_ratio': 0.15, 'sgdclassifier__learning_rate': 'optimal', 'sgdclassifier__loss': 'hinge', 'sgdclassifier__max_iter': 1000, 'sgdclassifier__n_iter_no_change': 5, 'sgdclassifier__n_jobs': None, 'sgdclassifier__penalty': 'l2', 'sgdclassifier__power_t': 0.5, 'sgdclassifier__random_state': None, 'sgdclassifier__shuffle': True, 'sgdclassifier__tol': 0.001, 'sgdclassifier__validation_fraction': 0.1, 'sgdclassifier__verbose': 0, 'sgdclassifier__warm_start': False}
# score
#  0.9641682652781584
# coef_
# [[-4.68561872e-02 -4.72074825e-02  5.38254070e-02 -6.48351224e-02
#   -1.65230625e-15  7.03852891e-02]]
# intercept_
# [-1.04831816]
# fit
# 6 ['sofa_coagulation' 'sofa_cardiovascular' 'sofa_cns' 'sofa_renal' 'gender'
#  'charlson_comorbidity_index']
# decision function
#  [-1.23185288 -1.21966761 -1.17431117 ... -1.1308211  -1.15956625
#  -1.17317149]
# classification report
#                    precision    recall  f1-score   support
#
# Intubation False       0.96      1.00      0.98      7014
#  Intubation True       0.00      0.00      0.00       283
#
#         accuracy                           0.96      7297
#        macro avg       0.48      0.50      0.49      7297
#     weighted avg       0.92      0.96      0.94      7297
#
# Micro-averaged One-vs-Rest ROC AUC score:
# 0.50
# F:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but SGDClassifier was fitted without feature names
#   warnings.warn(
# F:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# F:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# F:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# '\nprint(\'linear SGDRegressor loss equivalent to SVR, loss = epsilon_insensitive, StandardScaler\')\nsgdSVRLinear = SGDRegressor(loss=\'epsilon_insensitive\', penalty=\'l2\', alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=1000, tol=0.001, shuffle=True, verbose=0, epsilon=0.1, random_state=None, learning_rate=\'invscaling\', eta0=0.01, power_t=0.25, early_stopping=False, validation_fraction=0.1, n_iter_no_change=5, warm_start=False, average=False)\nclf = make_pipeline(StandardScaler(), sgdSVRLinear)\n\nacc_score = []\nfor train_index , test_index in kf.split(X):\n    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]\n    y_train , y_test = y[train_index] , y[test_index]\n    \n    clf.fit(X_train, y_train)\n    y_pred = clf.predict(X_test)\n     \n    acc = accuracy_score(y_pred , y_test)\n    acc_score.append(acc)\n     \navg_acc_score = sum(acc_score)/k\nprint(\'accuracy of each fold - {}\'.format(acc_score))\nprint(\'Avg accuracy : {}\'.format(avg_acc_score))\n\noutcome_labels = [\'Intubation False\', \'Intubation True\']\n\nprint(\'parameters \n\', clf.get_params())\nprint(\'score \n\', clf.score(X_train, y_train))\nprint(clf[1].coef_)\nprint(clf[1].intercept_)\nprint(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)\n\nprint(\'classification report \n\', classification_report(y_test, y_pred, target_names=outcome_labels))\nmicro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")\nprint(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")\nprint(\'\n\')\n\nprint(\'linear SGDRegressor loss equivalent to SVR, loss = epsilon_insensitive, RobustScaler\')\nsgdSVRLinear = SGDRegressor(loss=\'epsilon_insensitive\', penalty=\'l2\', alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=1000, tol=0.001, shuffle=True, verbose=0, epsilon=0.1, random_state=None, learning_rate=\'invscaling\', eta0=0.01, power_t=0.25, early_stopping=False, validation_fraction=0.1, n_iter_no_change=5, warm_start=False, average=False)\nclf = make_pipeline(StandardScaler(), sgdSVRLinear)\n\nacc_score = []\nfor train_index , test_index in kf.split(X):\n    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]\n    y_train , y_test = y[train_index] , y[test_index]\n    \n    clf.fit(X_train, y_train)\n    y_pred = clf.predict(X_test)\n     \n    acc = accuracy_score(y_pred , y_test)\n    acc_score.append(acc)\n     \navg_acc_score = sum(acc_score)/k\nprint(\'accuracy of each fold - {}\'.format(acc_score))\nprint(\'Avg accuracy : {}\'.format(avg_acc_score))\n\noutcome_labels = [\'Intubation False\', \'Intubation True\']\n\nprint(\'parameters \n\', clf.get_params())\nprint(\'score \n\', clf.score(X_train, y_train))\nprint(clf[1].coef_)\nprint(clf[1].intercept_)\nprint(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)\n\nprint(\'classification report \n\', classification_report(y_test, y_pred, target_names=outcome_labels))\nmicro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")\nprint(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")\nprint(\'\n\')\n'

# %% [markdown]
# +++ 1_2_1b

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier, SGDRegressor, RidgeCV, LassoCV
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split, KFold
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.metrics import classification_report, roc_auc_score
from collections import Counter
from imblearn.over_sampling import SMOTE, SMOTEN

#'''
pd.set_option("display.max_columns", None)
#X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state = 0) #train split

print('SMOTEN non-contin')
print()

smoten_noncontin = pd.read_csv('smoten_noncontin.csv', index_col=False)

X = smoten_noncontin.drop('outcome',axis= 1)
y = smoten_noncontin['outcome']

print('rbf SVM C StandardScaler')
clf = make_pipeline(StandardScaler(), SVC(kernel='rbf', C=1.0))

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    rbf = SVC(kernel='rbf', C=1, decision_function_shape='ovo').fit(X_train, y_train)

    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']
print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('dual_coef_')
print(clf[1].dual_coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf.decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('rbf SVM C RobustScaler')
clf = make_pipeline(RobustScaler(), SVC(kernel='rbf', C=1.0))
clf.fit(X_train, y_train)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']
print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('dual_coef_')
print(clf[1].dual_coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf.decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('polynomial SVM C StandardScaler')
clf = make_pipeline(StandardScaler(), SVC(kernel='poly', C=1.0))
clf.fit(X_train, y_train)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]

    poly = SVC(kernel='poly', degree=2, C=1, decision_function_shape='ovo').fit(X_train, y_train)    
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']
print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('dual_coef_')
print(clf[1].dual_coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf.decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('polynomial SVM C RobustScaler')
clf = make_pipeline(RobustScaler(), SVC(kernel='poly', C=1.0))
clf.fit(X_train, y_train)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']
print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('dual_coef_')
print(clf[1].dual_coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf.decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('sigmoid SVM C StandardScaler')
clf = make_pipeline(StandardScaler(), SVC(kernel='sigmoid', C=1.0))
clf.fit(X_train, y_train)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    sig = SVC(kernel='sigmoid', C=1, decision_function_shape='ovo').fit(X_train, y_train)
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']
print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('dual_coef_')
print(clf[1].dual_coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf.decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('sigmoid SVM C RobustScaler')
clf = make_pipeline(RobustScaler(), SVC(kernel='sigmoid', C=1.0))
clf.fit(X_train, y_train)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']
print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('dual_coef_')
print(clf[1].dual_coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf.decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')


print('Encoded non-contin')
print()

knn_imputed_noncontin = pd.read_csv('knn_imputed_noncontin.csv', index_col=False)

X = knn_imputed_noncontin.drop('outcome',axis= 1)
y = knn_imputed_noncontin['outcome']

print('rbf SVM C StandardScaler')
clf = make_pipeline(StandardScaler(), SVC(kernel='rbf', C=1.0))

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    rbf = SVC(kernel='rbf', C=1, decision_function_shape='ovo').fit(X_train, y_train)

    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']
print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('dual_coef_')
print(clf[1].dual_coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf.decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('rbf SVM C RobustScaler')
clf = make_pipeline(RobustScaler(), SVC(kernel='rbf', C=1.0))
clf.fit(X_train, y_train)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']
print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('dual_coef_')
print(clf[1].dual_coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf.decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('polynomial SVM C StandardScaler')
clf = make_pipeline(StandardScaler(), SVC(kernel='poly', C=1.0))
clf.fit(X_train, y_train)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]

    poly = SVC(kernel='poly', degree=2, C=1, decision_function_shape='ovo').fit(X_train, y_train)    
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']
print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('dual_coef_')
print(clf[1].dual_coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf.decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('polynomial SVM C RobustScaler')
clf = make_pipeline(RobustScaler(), SVC(kernel='poly', C=1.0))
clf.fit(X_train, y_train)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']
print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('dual_coef_')
print(clf[1].dual_coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf.decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('sigmoid SVM C StandardScaler')
clf = make_pipeline(StandardScaler(), SVC(kernel='sigmoid', C=1.0))
clf.fit(X_train, y_train)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    sig = SVC(kernel='sigmoid', C=1, decision_function_shape='ovo').fit(X_train, y_train)
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']
print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('dual_coef_')
print(clf[1].dual_coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf.decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')

print('sigmoid SVM C RobustScaler')
clf = make_pipeline(RobustScaler(), SVC(kernel='sigmoid', C=1.0))
clf.fit(X_train, y_train)

acc_score = []
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
     
    acc = accuracy_score(y_pred , y_test)
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/k
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))

outcome_labels = ['Intubation False', 'Intubation True']
print('parameters \n', clf.get_params())
print('score \n', clf.score(X_train, y_train))
print('dual_coef_')
print(clf[1].dual_coef_)
print('intercept_')
print(clf[1].intercept_)
print('fit')
print(clf.fit(X_train, y_train).n_features_in_, clf.fit(X_train, y_train).feature_names_in_)
print('decision function \n', clf.decision_function(X_test))
print('classification report \n', classification_report(y_test, y_pred, target_names=outcome_labels))
micro_roc_auc_ovr = roc_auc_score(y_test, y_pred, multi_class="ovr", average="micro")
print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")
print('\n')
# Out:
# SMOTEN non-contin
#
# rbf SVM C StandardScaler
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14448\968276187.py in <module>
#      28
#      29 acc_score = []
# ---> 30 for train_index , test_index in kf.split(X):
#      31     X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
#      32     y_train , y_test = y[train_index] , y[test_index]
#
# NameError: name 'kf' is not defined
